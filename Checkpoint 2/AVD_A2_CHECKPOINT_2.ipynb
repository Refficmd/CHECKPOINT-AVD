# %% [markdown]
# # CHECKPOINT 2

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Data Understanding
#
# Dataset ini diperoleh dari [Kaggle - Gym members excercise](https://www.kaggle.com/datasets/valakhorasani/gym-members-exercise-dataset)

# %%
df = pd.read_csv("/content/gym_members_exercise_tracking (1).csv")

df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %% [markdown]
# # Cek jumlah baris dan kolom

# %%
print(f"Dataset memiliki {df.shape[0]} baris dan {df.shape[1]} kolom.\n")
# Out:
# Dataset memiliki 973 baris dan 15 kolom.

# %% [markdown]
# # Cek tipe data setiap kolom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
# ...

# %% [markdown]
# # Tinjau 5 Baris Awal & Akhir Dataset

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %% [markdown]
# # Statistik deskriptif

# %%
df.describe()
# Out:
#               Age  Weight (kg)  Height (m)     Max_BPM     Avg_BPM  \
# count  973.000000   973.000000   973.00000  973.000000  973.000000
# mean    38.683453    73.854676     1.72258  179.883864  143.766701
# std     12.180928    21.207500     0.12772   11.525686   14.345101
# min     18.000000    40.000000     1.50000  160.000000  120.000000
# 25%     28.000000    58.100000     1.62000  170.000000  131.000000
# 50%     40.000000    70.000000     1.71000  180.000000  143.000000
# 75%     49.000000    86.000000     1.80000  190.000000  156.000000
# max     59.000000   129.900000     2.00000  199.000000  169.000000
#
#        Resting_BPM  Session_Duration (hours)  Calories_Burned  Fat_Percentage  \
# count   973.000000                973.000000       973.000000      973.000000
# mean     62.223022                  1.256423       905.422405       24.976773
# std       7.327060                  0.343033       272.641516        6.259419
# ...

# %% [markdown]
# # Analisis korelasi

# %%
corr_matrix = df[["Workout_Frequency (days/week)", "Session_Duration (hours)"]].corr()

print("\nMatriks Korelasi:")
print(corr_matrix)
# Out:
# Matriks Korelasi:
#                                Workout_Frequency (days/week)  \
# Workout_Frequency (days/week)                        1.00000
# Session_Duration (hours)                             0.64414
#
#                                Session_Duration (hours)
# Workout_Frequency (days/week)                   0.64414
# Session_Duration (hours)                        1.00000

# %% [markdown]
# # Data cleaning

# %% [markdown]
# # 1. Missing values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# Age                              0.0
# Gender                           0.0
# Weight (kg)                      0.0
# Height (m)                       0.0
# Max_BPM                          0.0
# Avg_BPM                          0.0
# Resting_BPM                      0.0
# Session_Duration (hours)         0.0
# Calories_Burned                  0.0
# Workout_Type                     0.0
# Fat_Percentage                   0.0
# Water_Intake (liters)            0.0
# Workout_Frequency (days/week)    0.0
# Experience_Level                 0.0
# BMI                              0.0
# dtype: float64

# %% [markdown]
# Tidak ada nilai yang hilang (missing values)

# %% [markdown]
# # 2. Duplicated Values

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Age, Gender, Weight (kg), Height (m), Max_BPM, Avg_BPM, Resting_BPM, Session_Duration (hours), Calories_Burned, Workout_Type, Fat_Percentage, Water_Intake (liters), Workout_Frequency (days/week), Experience_Level, BMI]
# Index: []

# %% [markdown]
# Tidak ada duplicated values

# %% [markdown]
# # 3. Outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                          Persentase Outliers
# Age                                       0.000000
# Weight (kg)                               0.924974
# Height (m)                                0.000000
# Max_BPM                                   0.000000
# Avg_BPM                                   0.000000
# Resting_BPM                               0.000000
# Session_Duration (hours)                  0.000000
# Calories_Burned                           1.027749
# Fat_Percentage                            0.000000
# Water_Intake (liters)                     0.000000
# Workout_Frequency (days/week)             0.000000
# Experience_Level                          0.000000
# BMI                                       2.569373

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %% [markdown]
# Dikarenakan presentase yang tidak terlalu tinggi namun merupakan variable yang penting, maka dilakukan imputasi dengan metode yang paling sesuai, yaitu Winsorizing karena tetap mempertahankan struktur data tanpa membuang nilai ekstrem

# %% [markdown]
# # Melakukan imputasi

# %%
columns_to_impute = ["Calories_Burned", "BMI"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Menggunakan .loc[] agar tidak muncul SettingWithCopyWarning
    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %% [markdown]
# # Pengecekan ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                          Persentase Outliers
# Age                                       0.000000
# Weight (kg)                               0.924974
# Height (m)                                0.000000
# Max_BPM                                   0.000000
# Avg_BPM                                   0.000000
# Resting_BPM                               0.000000
# Session_Duration (hours)                  0.000000
# Calories_Burned                           0.000000
# Fat_Percentage                            0.000000
# Water_Intake (liters)                     0.000000
# Workout_Frequency (days/week)             0.000000
# Experience_Level                          0.000000
# BMI                                       0.000000

# %% [markdown]
# # Incosistent value

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Height (m)  Max_BPM  Avg_BPM  Resting_BPM  \
# 0     56    Male         88.3        1.71      180      157           60
# 1     46  Female         74.9        1.53      179      151           66
# 2     32  Female         68.1        1.66      167      122           54
# 3     25    Male         53.2        1.70      190      164           56
# 4     38    Male         46.1        1.79      188      158           68
# ..   ...     ...          ...         ...      ...      ...          ...
# 968   24    Male         87.1        1.74      187      158           67
# 969   25    Male         66.6        1.61      184      166           56
# 970   59  Female         60.4        1.76      194      120           53
# 971   32    Male        126.4        1.83      198      146           62
# 972   46    Male         88.7        1.63      166      146           66
#
#      Session_Duration (hours)  Calories_Burned Workout_Type  Fat_Percentage  \
# ...

# %% [markdown]
# Menurut saya, dataset yang saya pilih tidak ada nilai yang tidak konsisten

# %% [markdown]
# # Construct data

# %%
import random

df["Subscription_Length"] = np.random.randint(1, 36, size=len(df))

df["Attendance_Consistency"] = np.random.randint(50, 101, size=len(df))
time_prefs = ["Morning", "Afternoon", "Evening"]
df["Preferred_Workout_Time"] = [random.choice(time_prefs) for _ in range(len(df))]

class_participation = ["Yes", "No"]
df["Class_Participation"] = [random.choice(class_participation) for _ in range(len(df))]

trainer_usage = ["Yes", "No"]
df["Trainer_Usage"] = [random.choice(trainer_usage) for _ in range(len(df))]

df["Customer_Feedback_Score"] = np.random.randint(1, 11, size=len(df))

referral_sources = ["Social Media", "Friend", "Ads"]
df["Referral_Source"] = [random.choice(referral_sources) for _ in range(len(df))]


if "Session_Duration (hours)" in df.columns and "Calories_Burned" in df.columns:
    df["Calories_per_Hour"] = df["Calories_Burned"] / (df["Session_Duration (hours)"] + 1e-9)

# %%
df
# Out:
#      Age  Gender  Weight (kg)  Session_Duration (hours)  Calories_Burned  \
# 0     56    Male         88.3                      1.69           1313.0
# 1     46  Female         74.9                      1.30            883.0
# 2     32  Female         68.1                      1.11            677.0
# 3     25    Male         53.2                      0.59            532.0
# 4     38    Male         46.1                      0.64            556.0
# ..   ...     ...          ...                       ...              ...
# 968   24    Male         87.1                      1.57           1364.0
# 969   25    Male         66.6                      1.38           1260.0
# 970   59  Female         60.4                      1.72            929.0
# 971   32    Male        126.4                      1.10            883.0
# 972   46    Male         88.7                      0.75            542.0
#
#     Workout_Type  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %% [markdown]
# Kolom-kolom ini ditambahkan untuk memahami faktor yang mempengaruhi kesetiaan pelanggan, kebiasaan latihan, dan efektivitas program gym guna meningkatkan retensi anggota serta mengoptimalkan strategi pemasaran berbasis data.

# %% [markdown]
# # Data Reduction

# %%
irrelevant_cols = [
    "Height (m)",
    "Max_BPM",
    "Avg_BPM",
    "Resting_BPM",
    "Fat_Percentage",
    "Water_Intake (liters)",
    "BMI"
]
df.drop(columns=irrelevant_cols, inplace=True, errors="ignore")

df
# Out:
#      Age  Gender  Weight (kg)  Session_Duration (hours)  Calories_Burned  \
# 0     56    Male         88.3                      1.69           1313.0
# 1     46  Female         74.9                      1.30            883.0
# 2     32  Female         68.1                      1.11            677.0
# 3     25    Male         53.2                      0.59            532.0
# 4     38    Male         46.1                      0.64            556.0
# ..   ...     ...          ...                       ...              ...
# 968   24    Male         87.1                      1.57           1364.0
# 969   25    Male         66.6                      1.38           1260.0
# 970   59  Female         60.4                      1.72            929.0
# 971   32    Male        126.4                      1.10            883.0
# 972   46    Male         88.7                      0.75            542.0
#
#     Workout_Type  Workout_Frequency (days/week)  Experience_Level  \
# ...

# %% [markdown]
# Kolom tersebut dihapus karena tidak memberikan kontribusi langsung terhadap analisis retensi pelanggan dan efektivitas program latihan, sehingga mengurangi efisiensi dalam proses data mining.
